# %%
import matplotlib.pyplot as plt
import numpy as np
import data.loader as loader

# %%
data = loader.load('data/HPC2/00_02.tif')[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1, interpolation='none')

# %%
data = np.load('outputs/ani_15000_hpc2_02.npy', allow_pickle=True)[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/bi_1000_hpc2_02.npy', allow_pickle=True)[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/bi_1000_hpc2_02.npy', allow_pickle=True)[10]
fig = plt.figure(figsize=(30, 30))
# plt.axis('off')
plt.grid(False)
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/gauss_1000_hpc2_02.npy', allow_pickle=True)[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/tv_7000_hpc2_02.npy', allow_pickle=True)[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/wv_15000_hpc2_02.npy', allow_pickle=True)[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = loader.load('data/optosynth/raw/optosynth__1__20__5.tif')[10,20:100,150:300]
fig = plt.figure(figsize=(30, 30))
plt.axis('off')
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = loader.load('data/optosynth/clean/optosynth__1__20__5.tif')[10]
fig = plt.figure(figsize=(30, 30))
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)

# %%
data = np.load('outputs/tv_4000_optosynth_1.npy', allow_pickle=True)[10]
fig = plt.figure(figsize=(30, 30))
im = plt.imshow(data, cmap='grey', vmin=0, vmax=1)
